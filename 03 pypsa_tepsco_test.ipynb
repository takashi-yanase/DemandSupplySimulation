# %%
import pypsa_tepsco_test

pypsa_tepsco_test.scraping_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pypsa_tepsco_test
#       2 pypsa_tepsco_test.scraping_data()
#
# File c:\Users\takashi-yanase\Documents\PyPSA\DemandSupplySimulation\pypsa_tepsco_test.py:4
#       2 import warnings
#       3 import requests
# ----> 4 from bs4 import BeautifulSoup
#       5 import pandas as pd
#       7 # 風力・太陽光発電設備のデータをスクレイピングして取得・保存
#
# ModuleNotFoundError: No module named 'bs4'
